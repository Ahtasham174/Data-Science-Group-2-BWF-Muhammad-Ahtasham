# %% [markdown]
# # Task 18 ->Introduction to Seaborn (visualization with Seaborn)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %% [markdown]
# ### Load the dataset

# %%
file_path = 'HRDataset_v14.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ### Display the first few rows of the dataset

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %% [markdown]
# # A. Scatter Plot
# ## Using Simple Scatter Plot with different scatter point sizes:

# %% [markdown]
# ### 1. Scatter Plot of Salary vs. Engagement Survey:

# %%
plt.figure(figsize=(10, 6))
sns.relplot(data=df, x='Salary', y='EngagementSurvey',kind='scatter', hue='GenderID', palette='dark',size='Absences')
plt.title('Salary vs. Engagement Survey by Gender')
plt.xlabel('Salary')
plt.ylabel('Engagement Survey Score')
plt.show()

# %% [markdown]
# ## Using Relational Plot as Scatter Plot showing relation with other features according to relation between them:

# %% [markdown]
# ### 2. Scatter Plot of Salary vs. Performance Score:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Salary', y='PerformanceScore', hue='MaritalStatusID', palette='viridis')
plt.title('Salary vs. Performance Score by Marital Status')
plt.xlabel('Salary')
plt.ylabel('Performance Score')
plt.show()

# %% [markdown]
# ## More Visualization in Scatter Plot on Dataset:

# %% [markdown]
# ### 3. Scatter Plot of Engagement Survey vs. Emp Satisfaction by Gender:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='EngagementSurvey', y='EmpSatisfaction', hue='Sex', style='Sex', palette='husl')
plt.title('Engagement Survey vs. Employee Satisfaction by Gender')
plt.xlabel('Engagement Survey')
plt.ylabel('Employee Satisfaction')
plt.show()

# %% [markdown]
# ### 4. Scatter Plot of Days Late in Last 30 Days vs. Absences by Department:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='DaysLateLast30', y='Absences', hue='Department', palette='pastel')
plt.title('Days Late in Last 30 Days vs. Absences by Department')
plt.xlabel('Days Late in Last 30 Days')
plt.ylabel('Absences')
plt.show()

# %% [markdown]
# ### 5. Scatter Plot of Salary vs. Age by Department:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='EngagementSurvey', y='Salary', hue='Department', palette='coolwarm')
plt.title('Salary vs. EngagementSurvey by Department')
plt.xlabel('EngagementSurvey')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### 6. Scatter Plot of Salary vs. Special Projects Count by Employment Status:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='SpecialProjectsCount', y='Salary', hue='EmploymentStatus', palette='pastel')
plt.title('Salary vs. Special Projects Count by Employment Status')
plt.xlabel('Special Projects Count')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### 7. Scatter Plot of Absences vs. Days Late Last 30 by Performance Score:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='DaysLateLast30', y='Absences', hue='PerformanceScore', palette='muted')
plt.title('Absences vs. Days Late in Last 30 Days by Performance Score')
plt.xlabel('Days Late in Last 30 Days')
plt.ylabel('Absences')
plt.show()

# %% [markdown]
# ### 8. Scatter Plot of Engagement Survey vs. Absences by Recruitment Source:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='EngagementSurvey', y='Absences', hue='RecruitmentSource', palette='Set2')
plt.title('Engagement Survey vs. Absences by Recruitment Source')
plt.xlabel('Engagement Survey')
plt.ylabel('Absences')
plt.show()

# %% [markdown]
# ### 9. Scatter Plot of Engagement Survey vs. Emp Satisfaction by Marital Status:

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='EngagementSurvey', y='EmpSatisfaction', hue='MaritalDesc', palette='viridis')
plt.title('Engagement Survey vs. Employee Satisfaction by Marital Status')
plt.xlabel('Engagement Survey')
plt.ylabel('Employee Satisfaction')
plt.show()

# %% [markdown]
# # B. Line Plot
# ## Simple Line Plot With Error Bar
# ### 1. Line Plot of Salary over Age:

# %%
plt.figure(figsize=(10, 6))
df['Age'] = pd.to_datetime('today').year - pd.to_datetime(df['DOB']).dt.year
sns.lineplot(data=df, x='Age', y='Salary', hue='GenderID', palette='dark')
plt.title('Salary over Age by Gender')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\AppData\Local\Temp\ipykernel_27012\1551277671.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Age'] = pd.to_datetime('today').year - pd.to_datetime(df['DOB']).dt.year
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Line Subplot with Added Markers, No Errorbar and Dashed Lines

# %% [markdown]
# ### 2. Line Plot of Salary over Years of Service by Gender:

# %%
plt.figure(figsize=(10, 6))
df['YearsOfService'] = (pd.to_datetime('today') - pd.to_datetime(df['DateofHire'])).dt.days // 365
sns.relplot(data=df, x='YearsOfService', y='Salary', kind='line', style='Sex', hue='Sex', palette='Set2',markers=True, dashes=True, errorbar=None)
plt.title('Salary over Years of Service by Gender')
plt.xlabel('Years of Service')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## More Visualization in Line Plot on Dataset:

# %% [markdown]
# ### 3. Line Plot of Performance Score over Years of Service by Department:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='YearsOfService', y='PerformanceScore', hue='Department', palette='muted')
plt.title('Performance Score over Years of Service by Department')
plt.xlabel('Years of Service')
plt.ylabel('Performance Score')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 4. Line Plot of Absences over DaysLateLast30:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='DaysLateLast30', y='Absences', hue='GenderID', style='GenderID', markers=True, palette='muted')
plt.title('Absences over Days Late in Last 30 Days')
plt.xlabel('Days Late in Last 30 Days')
plt.ylabel('Absences')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 5. Line Plot of Salary over Age by Gender:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Age', y='Salary', hue='Sex', palette='coolwarm')
plt.title('Salary over Age by Gender')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 6. Line Plot of Salary over Engagement Survey by Gender:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='EngagementSurvey', y='Salary', hue='Sex', palette='dark')
plt.title('Salary over Engagement Survey by Gender')
plt.xlabel('Engagement Survey')
plt.ylabel('Salary')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 7. Line Plot of Absences over Age by Department:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Age', y='Absences', hue='Department', palette='muted')
plt.title('Absences over Age by Department')
plt.xlabel('Age')
plt.ylabel('Absences')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 8. Line Plot of Engagement Survey over Age by Performance Score:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='Age', y='EngagementSurvey', hue='PerformanceScore', palette='husl')
plt.title('Engagement Survey over Age by Performance Score')
plt.xlabel('Age')
plt.ylabel('Engagement Survey')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### 9. Line Plot of Emp Satisfaction over Years of Service by Marital Status:

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='YearsOfService', y='EmpSatisfaction', hue='MaritalDesc', palette='viridis')
plt.title('Employee Satisfaction over Years of Service by Marital Status')
plt.xlabel('Years of Service')
plt.ylabel('Employee Satisfaction')
plt.show()
# Out:
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Muhammad Ahtasham\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # C. Bar Plot
# ## Simple Relational Plot Using Catplot as similar to Relplot in line & scatter
# ### 1. Bar Plot of Average Salary by Department:

# %%
plt.figure(figsize=(12, 8))
sns.catplot(data=df, x='Department', y='Salary',kind='bar', estimator=np.mean, palette='Set3')
plt.title('Average Salary by Department')
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Bar Plot with No Confidence Interval

# %% [markdown]
# ### 2. Bar Plot of Employee Satisfaction by Marital Status:

# %%
sns.barplot(data=df, x='MaritalDesc', y='EmpSatisfaction', estimator=np.mean, palette='Blues', errorbar=None)
plt.title('Employee Satisfaction by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Employee Satisfaction')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## More Data Visualization Practice on Barplot

# %% [markdown]
# ### 3. Bar Plot of Average Emp Satisfaction by Manager:

# %%
sns.barplot(data=df, x='ManagerName', y='EmpSatisfaction', estimator=np.mean, palette='Greens')
plt.title('Average Employee Satisfaction by Manager')
plt.xlabel('Manager Name')
plt.ylabel('Average Employee Satisfaction')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 4. Bar Plot of Average Engagement Survey by Position:

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='Position', y='EngagementSurvey', estimator=np.mean, palette='pastel')
plt.title('Average Engagement Survey by Position')
plt.xlabel('Position')
plt.ylabel('Average Engagement Survey')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 5. Bar Plot of Average Salary by Race:

# %%
sns.barplot(data=df, x='RaceDesc', y='Salary', estimator=np.mean, palette='coolwarm')
plt.title('Average Salary by Race')
plt.xlabel('Race')
plt.ylabel('Average Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 6. Bar Plot of Average Days Late in Last 30 Days by Gender:

# %%
sns.barplot(data=df, x='Sex', y='DaysLateLast30', estimator=np.mean, palette='pastel')
plt.title('Average Days Late in Last 30 Days by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Days Late in Last 30 Days')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Bar Plot of Average Engagement Survey by Department:

# %%
sns.barplot(data=df, x='Department', y='EngagementSurvey', estimator=np.mean, palette='dark')
plt.title('Average Engagement Survey by Department')
plt.xlabel('Department')
plt.ylabel('Average Engagement Survey')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 8. Bar Plot of Average Absences by Employment Status:

# %%
sns.barplot(data=df, x='EmploymentStatus', y='Absences', estimator=np.mean, palette='husl')
plt.title('Average Absences by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Average Absences')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 9. Bar Plot of Average Engagement Survey by Manager Name:

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x='ManagerName', y='EngagementSurvey', estimator=np.mean, palette='viridis')
plt.title('Average Engagement Survey by Manager')
plt.xlabel('Manager Name')
plt.ylabel('Average Engagement Survey')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # D. Count Plot
# ## Simple Relational Plot Using Catplot as similar to Relplot in line & scatter
# ### 1. Count Plot of Employees by Department:

# %%
plt.figure(figsize=(12, 8))
sns.catplot(data=df, kind="count", x='Department', palette='Set2')
plt.title('Number of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 2. Count Plot of Employees by Employment Status:

# %%
sns.countplot(data=df, x='EmploymentStatus', palette='Set3')
plt.title('Number of Employees by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## More Data Visualization Practice on Countplot

# %% [markdown]
# ### 3. Count Plot of Employees by Race:

# %%
sns.countplot(data=df, x='RaceDesc', palette='Set3')
plt.title('Number of Employees by Race')
plt.xlabel('Race')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 4. Count Plot of Employees by Recruitment Source:

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='RecruitmentSource', palette='Set2')
plt.title('Number of Employees by Recruitment Source')
plt.xlabel('Recruitment Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 5. Count Plot of Employees by Department:

# %%
sns.countplot(data=df, x='Department', palette='coolwarm')
plt.title('Number of Employees by Department')
plt.xlabel('Department')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 6. Count Plot of Employees by Employment Status:

# %%
sns.countplot(data=df, x='EmploymentStatus', palette='pastel')
plt.title('Number of Employees by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Count Plot of Employees by Recruitment Source:

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='RecruitmentSource', palette='muted')
plt.title('Number of Employees by Recruitment Source')
plt.xlabel('Recruitment Source')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 8. Count Plot of Employees by Performance Score:

# %%
sns.countplot(data=df, x='PerformanceScore', palette='husl')
plt.title('Number of Employees by Performance Score')
plt.xlabel('Performance Score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 9. Count Plot of Employees by Manager Name:

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='ManagerName', palette='viridis')
plt.title('Number of Employees by Manager Name')
plt.xlabel('Manager Name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Box Plot
# ## Simple Relational Plot Using Catplot as similar to Relplot in line & scatter
# ### 1. Box Plot of Salary by Department:

# %%
sns.catplot(data=df, x='Department', kind='box', y='Salary', palette='Blues')
plt.title('Salary Distribution by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Removing Outliers

# %%
sns.boxplot(data=df, x='Department', y='Salary', palette='Blues', sym='')
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# ## Changing the whiskers
# The whiskers are the two lines outside the box, that go from the minimum to the lower quartile (the start of the box) and then from the upper quartile (the end of the box) to the maximum

# %%
sns.boxplot(data=df, x='Department', y='Salary', palette='Blues', sym='', whis=[0, 100], whiskerprops={'color': 'red'})
# Out:
# <Axes: xlabel='Department', ylabel='Salary'>

# %% [markdown]
# ### 2. Box Plot of Engagement Survey by Performance Score:

# %%
sns.boxplot(data=df, x='PerformanceScore', y='EngagementSurvey', palette='Greens')
plt.title('Engagement Survey by Performance Score')
plt.xlabel('Performance Score')
plt.ylabel('Engagement Survey')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## More Data Visualization Using Box Plot

# %% [markdown]
# ### 3. Box Plot of Salary by Employment Status:

# %%
sns.boxplot(data=df, x='EmploymentStatus', y='Salary', palette='Greens')
plt.title('Salary by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 4. Box Plot of Employee Satisfaction by Gender:

# %%
sns.boxplot(data=df, x='Sex', y='EmpSatisfaction', palette='Blues')
plt.title('Employee Satisfaction by Gender')
plt.xlabel('Gender')
plt.ylabel('Employee Satisfaction')
plt.show()

# %% [markdown]
# ### 5. Box Plot of Salary by Department:

# %%
sns.boxplot(data=df, x='Department', y='Salary', palette='coolwarm')
plt.title('Salary by Department')
plt.xlabel('Department')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 6. Box Plot of Days Late in Last 30 Days by Recruitment Source:

# %%
sns.boxplot(data=df, x='RecruitmentSource', y='DaysLateLast30', palette='pastel')
plt.title('Days Late in Last 30 Days by Recruitment Source')
plt.xlabel('Recruitment Source')
plt.ylabel('Days Late in Last 30 Days')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 7. Box Plot of Absences by Employment Status:

# %%
sns.boxplot(data=df, x='EmploymentStatus', y='Absences', palette='muted')
plt.title('Absences by Employment Status')
plt.xlabel('Employment Status')
plt.ylabel('Absences')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 8. Box Plot of Engagement Survey by Performance Score:

# %%
sns.boxplot(data=df, x='PerformanceScore', y='EngagementSurvey', palette='husl')
plt.title('Engagement Survey by Performance Score')
plt.xlabel('Performance Score')
plt.ylabel('Engagement Survey')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 9. Box Plot of Employee Satisfaction by Manager Name:

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='ManagerName', y='EmpSatisfaction', palette='viridis')
plt.title('Employee Satisfaction by Manager Name')
plt.xlabel('Manager Name')
plt.ylabel('Employee Satisfaction')
plt.xticks(rotation=45)
plt.show()
